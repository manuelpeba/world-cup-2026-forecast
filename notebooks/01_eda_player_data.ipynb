# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

from src.utils.config import PROCESSED_DATA_DIR
import pandas as pd

df = pd.read_parquet(PROCESSED_DATA_DIR / "team_match_features.parquet")

print(df.shape)
df.head()
# Out:
# (98142, 24)
#         date    team_a         team_b  goals_a  goals_b  \
# 0 2012-09-25  Abkhazia        Artsakh        1        1
# 1 2012-10-21   Artsakh       Abkhazia        3        0
# 2 2014-06-01  Abkhazia      Occitania        1        1
# 3 2014-06-02     Sápmi       Abkhazia        1        2
# 4 2014-06-04  Abkhazia  South Ossetia        0        0
#
#                   tournament         city     country  neutral_venue  year  \
# 0                   Friendly      Sukhumi     Georgia          False  2012
# 1                   Friendly  Stepanakert  Azerbaijan          False  2012
# 2  CONIFA World Football Cup    Östersund      Sweden           True  2014
# 3  CONIFA World Football Cup    Östersund      Sweden          False  2014
# 4  CONIFA World Football Cup    Östersund      Sweden           True  2014
#
#    ...  goals_against win draw  loss  points  rolling_goals_scored  \
# 0  ...              1   0    1     0       1                   NaN
# 1  ...              3   0    0     1       0                   NaN
# 2  ...              1   0    1     0       1                   NaN
# 3  ...              1   1    0     0       3                   NaN
# 4  ...              0   0    1     0       1                   NaN
#
#    rolling_goals_conceded  rolling_goal_diff  rolling_win_rate  rolling_points
# 0                     NaN                NaN               NaN             NaN
# 1                     NaN                NaN               NaN             NaN
# 2                     NaN                NaN               NaN             NaN
# 3                     NaN                NaN               NaN             NaN
# 4                     NaN                NaN               NaN             NaN
#
# [5 rows x 24 columns]
